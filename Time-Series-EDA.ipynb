# %%
import yfinance as yf

# Fetch data for Tesla (TSLA)
tsla_data = yf.download('TSLA')

# Display the data
print(tsla_data)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2024-10-02  247.550003  251.160004  241.500000  249.020004  249.020004
# 2024-10-03  244.479996  249.789993  237.809998  240.660004  240.660004
# 2024-10-04  246.690002  250.960007  244.580002  250.080002  250.080002
# 2024-10-07  249.000000  249.830002  240.699997  240.830002  240.830002
# 2024-10-08  243.559998  246.210007  240.559998  244.500000  244.500000
#
#                Volume
# Date
# ...

# %%
type(tsla_data)
# Out:
# pandas.core.frame.DataFrame

# %%
tsla_data.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500

# %%
tsla_data.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-10-02  247.550003  251.160004  241.500000  249.020004  249.020004
# 2024-10-03  244.479996  249.789993  237.809998  240.660004  240.660004
# 2024-10-04  246.690002  250.960007  244.580002  250.080002  250.080002
# 2024-10-07  249.000000  249.830002  240.699997  240.830002  240.830002
# 2024-10-08  243.559998  246.210007  240.559998  244.500000  244.500000
#
#               Volume
# Date
# 2024-10-02  93983900
# 2024-10-03  80729200
# 2024-10-04  86573200
# 2024-10-07  68113300
# 2024-10-08  56132800

# %%
import matplotlib.pyplot as plt

plt.plot(tsla_data)

# %%
tsla_data['High'].plot(figsize=(12,6))
# Out:
# <Axes: xlabel='Date'>

# %%
tsla_data['High'].plot(xlim=['2020-01-01', '2024-10-08'],figsize=(20,6))
# Out:
# <Axes: xlabel='Date'>

# %%
tsla_data.index
# Out:
# DatetimeIndex(['2010-06-29', '2010-06-30', '2010-07-01', '2010-07-02',
#                '2010-07-06', '2010-07-07', '2010-07-08', '2010-07-09',
#                '2010-07-12', '2010-07-13',
#                ...
#                '2024-09-25', '2024-09-26', '2024-09-27', '2024-09-30',
#                '2024-10-01', '2024-10-02', '2024-10-03', '2024-10-04',
#                '2024-10-07', '2024-10-08'],
#               dtype='datetime64[ns]', name='Date', length=3594, freq=None)

# %%
tsla_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3594 entries, 2010-06-29 to 2024-10-08
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       3594 non-null   float64
#  1   High       3594 non-null   float64
#  2   Low        3594 non-null   float64
#  3   Close      3594 non-null   float64
#  4   Adj Close  3594 non-null   float64
#  5   Volume     3594 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 196.5 KB

# %%
df_tsla = tsla_data.reset_index()

# %%
df_tsla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3594 entries, 0 to 3593
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3594 non-null   datetime64[ns]
#  1   Open       3594 non-null   float64
#  2   High       3594 non-null   float64
#  3   Low        3594 non-null   float64
#  4   Close      3594 non-null   float64
#  5   Adj Close  3594 non-null   float64
#  6   Volume     3594 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 196.7 KB

# %%
df_tsla.head(10)
# Out:
#         Date      Open      High       Low     Close  Adj Close     Volume
# 0 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 1 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 3 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 4 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500
# 5 2010-07-07  1.093333  1.108667  0.998667  1.053333   1.053333  103825500
# 6 2010-07-08  1.076000  1.168000  1.038000  1.164000   1.164000  115671000
# 7 2010-07-09  1.172000  1.193333  1.103333  1.160000   1.160000   60759000
# 8 2010-07-12  1.196667  1.204667  1.133333  1.136667   1.136667   33037500
# 9 2010-07-13  1.159333  1.242667  1.126667  1.209333   1.209333   40201500

# %%
df_tsla_reversed['High'].max()

# %%
df_tsla_reversed = df_tsla.set_index('Date')

# %%
# df_tsla_reversed['High'].idmax()

tsla_data['High'].idxmax()
# Out:
# Timestamp('2021-11-04 00:00:00')

# %%
df_tsla_reversed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3594 entries, 2010-06-29 to 2024-10-08
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       3594 non-null   float64
#  1   High       3594 non-null   float64
#  2   Low        3594 non-null   float64
#  3   Close      3594 non-null   float64
#  4   Adj Close  3594 non-null   float64
#  5   Volume     3594 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 196.5 KB

# %%
df_tsla_reversed['Open'].resample(rule=('M')).max().plot(xlim=['2020-01-01', '2024-10-08'], kind='line', figsize=(20,8))
# Out:
# C:\Users\muham\AppData\Local\Temp\ipykernel_25452\114760978.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_tsla_reversed['Open'].resample(rule=('M')).max().plot(xlim=['2020-01-01', '2024-10-08'], kind='line', figsize=(20,8))
# <Axes: xlabel='Date'>
